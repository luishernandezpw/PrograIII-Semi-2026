# %% [markdown]
# <a href="https://colab.research.google.com/github/luishernandezpw/PrograIII-Semi-2026/blob/master/miPrimerProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "HOla Chicos de progra III"
print(saludo, "Primera letra del saludo", saludo[0:4])

num1 = 5.25
print(num1)

booleano = True
print(booleano)
# Out:
# HOla Chicos de progra III Primera letra del saludo HOla
# 5.25
# True

# %%
print("Sumar dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) + float(num2)

print(type(num1), type(num2), type(respuesta))

print("Respuesta: ", respuesta)

respuesta = "Ssuma completa"
print(respuesta, type(respuesta))
# Out:
# Sumar dos numeros:
# Num 1: 5.5
# Num 2: 6
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta:  11.5
# Ssuma completa <class 'str'>

# %%
print("Restar dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) - float(num2)
print("Respuesta: ", respuesta)
# Out:
# Restar dos numeros:
# Num 1: 5.5
# Num 2: 6
# Respuesta:  -0.5

# %%
print("Multiplicar dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) * float(num2)
print("Respuesta: ", respuesta)
# Out:
# Multiplicar dos numeros:
# Num 1: 5
# Num 2: 3
# Respuesta:  15.0

# %%
print("Dividir dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) / float(num2)
print("Respuesta: ", respuesta)
# Out:
# Dividir dos numeros:
# Num 1: 15
# Num 2: 3
# Respuesta:  5.0

# %%
saludo = "Hola chicos de Progra"
print("Primer Elemento de la cadena", saludo[0])
print("Rango en una cadena", saludo[0:4])
print("Ultimo Elemento", saludo[-1])
print("Ultimo Elemento", saludo[len(saludo)-1])
print("Valores en medio, sin espesificar ultimo valor", saludo[5:])
print("Sin valor al inicio", saludo[:4])
print("Contar del final", saludo[5:-1])
# Out:
# Primer Elemento de la cadena H
# Rango en una cadena Hola
# Ultimo Elemento a
# Ultimo Elemento a
# Valores en medio, sin espesificar ultimo valor chicos de Progra
# Sin valor al inicio Hola
# Contar del final chicos de Progr
